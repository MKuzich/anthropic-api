# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
# Function to generate a new dataset
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
        "format": "json" or "python" or "regex"
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
# Generate the dataset and write it to 'dataset.json'
dataset = generate_dataset()
with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
# Function to grade a test case + output using a model
def grade_by_model(test_case, output):
    eval_prompt = f"""
You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.

Original Task:
<task>
{test_case["task"]}
</task>

Solution to Evaluate:
<solution>
{output}
</solution>

Output Format
Provide your evaluation as a structured JSON object with the following fields, in this specific order:
- "strengths": An array of 1-3 key strengths
- "weaknesses": An array of 1-3 key areas for improvement
- "reasoning": A concise explanation of your overall assessment
- "score": A number between 1-10

Respond with JSON. Keep your response concise and direct.
Example response shape:
{{
    "strengths": string[],
    "weaknesses": string[],
    "reasoning": string,
    "score": number
}}
    """

    messages = []
    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "```json")
    eval_text = chat(messages, stop_sequences=["```"])
    return json.loads(eval_text)

# %%
# Passes a test case into Claude
def run_prompt(test_case):
    prompt = f"""
Please solve the following task:

{test_case["task"]}
"""

    messages = []
    add_user_message(messages, prompt)
    output = chat(messages)
    return output

# %%
# Function to execute a single test case and grade the output
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)

    model_grade = grade_by_model(test_case, output)
    score = model_grade["score"]
    reasoning = model_grade["reasoning"]

    return {
        "output": output,
        "test_case": test_case,
        "score": score,
        "reasoning": reasoning,
    }

# %%
from statistics import mean


def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    average_score = mean([result["score"] for result in results])
    print(f"Average score: {average_score}")

    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)
# Out:
# Average score: 5.666666666666667

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "# AWS S3 Bucket Name Parser\n\nHere's a solution to extract the bucket name from an S3 URI:\n\n```python\ndef parse_s3_bucket_name(s3_uri):\n    \"\"\"\n    Extract bucket name from an S3 URI.\n    \n    Args:\n        s3_uri (str): S3 URI in format 's3://bucket-name/path/to/file'\n    \n    Returns:\n        str: The bucket name\n    \n    Raises:\n        ValueError: If the URI is not a valid S3 URI\n    \"\"\"\n    if not s3_uri.startswith('s3://'):\n        raise ValueError(\"Invalid S3 URI: must start with 's3://'\")\n    \n    # Remove 's3://' prefix\n    remainder = s3_uri[5:]\n    \n    # Extract bucket name (everything before the first '/')\n    bucket_name = remainder.split('/')[0]\n    \n    if not bucket_name:\n        raise ValueError(\"Invalid S3 URI: bucket name is empty\")\n    \n    return bucket_name\n\n\n# Test cases\ntest_cases = [\n    's3://my-bucket/path/to/file.txt',\n    's3://another-bucket/file.txt',\n    's3://my-bucket/',\n    's3://my-bucket',\n]\n\nfor uri in test_cases:\n    try:\n        bucket = parse_s3_bucket_name(uri)\n        print(f\"URI: {uri} -> Bucket: {bucket}\")\n    except ValueError as e:\n        print(f\"URI: {uri} -> Error: {e}\")\n```\n\n**Output:**\n```\nURI: s3://my-bucket/path/to/file.txt -> Bucket: my-bucket\nURI: s3://another-bucket/file.txt -> Bucket: another-bucket\nURI: s3://my-bucket/ -> Bucket: my-bucket\nURI: s3://my-bucket -> Bucket: my-bucket\n```\n\n## Alternative using Regular Expressions\n\n```python\nimport re\n\ndef parse_s3_bucket_name_regex(s3_uri):\n    \"\"\"\n    Extract bucket name from S3 URI using regex.\n    \"\"\"\n    match = re.match(r's3://([^/]+)/?.*', s3_uri)\n    if not match:\n        raise ValueError(\"Invalid S3 URI format\")\n    return match.group(1)\n\n\n# Test\nprint(parse_s3_bucket_name_regex('s3://my-bucket/path/to/file.txt'))  # my-bucket\n```\n\n## Using urllib.parse\n\n```python\nfrom urllib.parse import urlparse\n\ndef parse_s3_bucket_name_urllib(s3_uri):\n    \"\"\"\n    Extract bucket name from S3 URI using urllib.\n    \"\"\"\n    parsed = urlparse(s3_uri)\n    if parsed.scheme != 's3':\n        raise ValueError(\"Invalid S3 URI: scheme must be 's3'\")\n    return parsed.netloc\n\n\n# Test\nprint(parse_s3_bucket_name_urllib('s3://my-bucket/path/to/file.txt'))  # my-bucket\n```\n\nAll three approaches work well. Choose based on your preferences:\n- **String manipulation**: Simple and no dependencies\n- **Regex**: Good for validation with complex patterns\n- **urllib.parse**: Elegant and handles URL parsing standards",
#     "test_case": {
#       "task": "Parse an AWS S3 bucket name from an S3 URI (e.g., 's3://my-bucket/path/to/file.txt') and extract just the bucket name",
#       "format": "regex"
#     },
#     "score": 7,
#     "reasoning": "The solution competently addresses the core task with multiple approaches and clear examples. However, it lacks AWS S3-specific validation and doesn't handle common URI variants encountered in distributed computing environments. The urllib.parse approach is the most robust technically, but even it would benefit from bucket name validation. These are practical limitations that could cause issues in production AWS environments."
#   },
#   {
#     "output": "# AWS Lambda CloudFormation Template Snippet\n\nHere's a JSON CloudFormation template snippet that defines a Lambda function with basic properties:\n\n```json\n{\n  \"AWSTemplateFormatVersion\": \"2010-09-09\",\n  \"Description\": \"CloudFormation template for AWS Lambda function\",\n  \"Resources\": {\n    \"MyLambdaFunction\": {\n      \"Type\": \"AWS::Lambda::Function\",\n      \"Properties\": {\n        \"FunctionName\": \"my-lambda-function\",\n        \"Runtime\": \"python3.11\",\n        \"Handler\": \"index.lambda_handler\",\n        \"Role\": \"arn:aws:iam::123456789012:role/lambda-execution-role\",\n        \"Code\": {\n          \"ZipFile\": \"def lambda_handler(event, context):\\n    return {'statusCode': 200, 'body': 'Hello from Lambda!'}\"\n        }\n      }\n    }\n  },\n  \"Outputs\": {\n    \"LambdaFunctionArn\": {\n      \"Description\": \"ARN of the Lambda function\",\n      \"Value\": {\n        \"Fn::GetAtt\": [\n          \"MyLambdaFunction\",\n          \"Arn\"\n        ]\n      }\n    },\n    \"LambdaFunctionName\": {\n      \"Description\": \"Name of the Lambda function\",\n      \"Value\": {\n        \"Ref\": \"MyLambdaFunction\"\n      }\n    }\n  }\n}\n```\n\n## Key Properties Explained:\n\n| Property | Description | Example |\n|----------|-------------|---------|\n| **FunctionName** | Name of the Lambda function | `my-lambda-function` |\n| **Runtime** | Execution environment | `python3.11`, `nodejs18.x`, `java11` |\n| **Handler** | Entry point for the function | `index.lambda_handler` (file.function) |\n| **Role** | IAM role ARN with Lambda execution permissions | `arn:aws:iam::123456789012:role/lambda-execution-role` |\n| **Code** | Function code (inline or S3 reference) | Shown with `ZipFile` |\n\n## Alternative Code Storage Methods:\n\n```json\n\"Code\": {\n  \"S3Bucket\": \"my-code-bucket\",\n  \"S3Key\": \"lambda-function.zip\"\n}\n```\n\nThis template creates a basic Lambda function that can be deployed using the AWS CloudFormation CLI or Console.",
#     "test_case": {
#       "task": "Create a JSON CloudFormation template snippet that defines an AWS Lambda function resource with basic properties (function name, runtime, handler, and role ARN)",
#       "format": "json"
#     },
#     "score": 7,
#     "reasoning": "The solution correctly addresses the core task by providing a valid JSON CloudFormation template with all four required basic properties. The documentation and structure are well-organized and helpful. However, the template has practical limitations: hardcoded values reduce reusability, and the absence of commonly-needed properties limits its real-world utility. These are not critical flaws for a basic snippet, but they prevent this from being a production-ready or fully exemplary solution."
#   },
#   {
#     "output": "# AWS EC2 Instance ID Validator\n\nHere's a Python function that validates AWS EC2 instance ID format:\n\n```python\nimport re\n\ndef validate_ec2_instance_id(instance_id):\n    \"\"\"\n    Validates whether a string matches the AWS EC2 instance ID format.\n    \n    Format: 'i-' followed by 17 alphanumeric characters (lowercase)\n    \n    Args:\n        instance_id (str): The instance ID string to validate\n        \n    Returns:\n        bool: True if valid, False otherwise\n        \n    Examples:\n        >>> validate_ec2_instance_id(\"i-0a1b2c3d4e5f6g7h8\")\n        True\n        >>> validate_ec2_instance_id(\"i-0a1b2c3d4e5f6g7\")\n        False\n        >>> validate_ec2_instance_id(\"0a1b2c3d4e5f6g7h8\")\n        False\n    \"\"\"\n    # Pattern: 'i-' followed by exactly 17 alphanumeric characters (0-9, a-f for hex)\n    pattern = r'^i-[a-f0-9]{17}$'\n    \n    return bool(re.match(pattern, instance_id))\n\n\n# Alternative implementation without regex\ndef validate_ec2_instance_id_no_regex(instance_id):\n    \"\"\"\n    Validates AWS EC2 instance ID format without using regex.\n    \n    Args:\n        instance_id (str): The instance ID string to validate\n        \n    Returns:\n        bool: True if valid, False otherwise\n    \"\"\"\n    # Check if it starts with 'i-' and has exactly 19 characters total\n    if not isinstance(instance_id, str) or len(instance_id) != 19:\n        return False\n    \n    if not instance_id.startswith('i-'):\n        return False\n    \n    # Check if remaining 17 characters are valid hexadecimal (0-9, a-f)\n    return all(c in '0123456789abcdef' for c in instance_id[2:])\n\n\n# Test cases\nif __name__ == \"__main__\":\n    # Valid instance IDs\n    valid_ids = [\n        \"i-0a1b2c3d4e5f6g7h8\",\n        \"i-1234567890abcdefg\",\n        \"i-aaaaaaaaaaaaaaaa0\",\n        \"i-0000000000000000a\",\n    ]\n    \n    # Invalid instance IDs\n    invalid_ids = [\n        \"i-0a1b2c3d4e5f6g7\",      # Too short\n        \"i-0a1b2c3d4e5f6g7h8j\",   # Too long\n        \"0a1b2c3d4e5f6g7h8\",      # Missing 'i-' prefix\n        \"I-0a1b2c3d4e5f6g7h8\",    # Wrong prefix case\n        \"i_0a1b2c3d4e5f6g7h8\",    # Wrong separator\n        \"i-0a1b2c3d4e5f6g7h!\",    # Invalid character\n        \"i-0a1b2c3d4e5f6g7hZ\",    # Uppercase letter\n        \"\",                         # Empty string\n        \"i-\",                       # Incomplete\n    ]\n    \n    print(\"=== Testing with regex version ===\")\n    print(\"Valid IDs:\")\n    for id_str in valid_ids:\n        result = validate_ec2_instance_id(id_str)\n        print(f\"  {id_str}: {result}\")\n    \n    print(\"\\nInvalid IDs:\")\n    for id_str in invalid_ids:\n        result = validate_ec2_instance_id(id_str)\n        print(f\"  {id_str}: {result}\")\n    \n    print(\"\\n=== Testing without regex version ===\")\n    print(\"Valid IDs:\")\n    for id_str in valid_ids:\n        result = validate_ec2_",
#     "test_case": {
#       "task": "Write a Python function that takes an AWS EC2 instance ID string and validates whether it matches the correct format (i-followed by 17 alphanumeric characters)",
#       "format": "python"
#     },
#     "score": 3,
#     "reasoning": "The solution demonstrates good structure and provides two implementation approaches with proper documentation. However, it contains a fundamental misunderstanding of AWS EC2 instance ID format. AWS EC2 instance IDs use lowercase alphanumeric characters [a-z0-9], not just hexadecimal [a-f0-9]. This critical bug affects both implementations and makes them reject legitimate AWS instance IDs. The test cases further compound this issue by being internally inconsistent and incomplete."
#   }
# ]
