# %%
# Install dependencies
# %pip install anthropic python-dotenv

# %%
# Load env variables
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
# Create an API client
from anthropic import Anthropic

client = Anthropic()
model = "claude-sonnet-4-6"

# %%
def add_user_message(messages, text):
    user_message = {
        "role": "user",
        "content": text
    }
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {
        "role": "assistant",
        "content": text
    }
    messages.append(assistant_message)

def chat(messages, system=None):

    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages
    }
    if system:
        params["system"] = system

    message = client.messages.create(**params)
    
    return message.content[0].text

# %%
# Simple prompt to test the system prompt functionality

messages = []

system = """
    You are a patient math tutor.
    Do not directly answer a student's questions.
    Guide them to a solution step by step.
    """

add_user_message(messages, "How do I solve the equation 2x+3=7 for x?")
answer = chat(messages, system)

answer
# Out:
# '## Solving 2x + 3 = 7\n\n**Goal:** Isolate x on one side of the equation.\n\n**Step 1: Subtract 3 from both sides**\n$$2x + 3 - 3 = 7 - 3$$\n$$2x = 4$$\n\n**Step 2: Divide both sides by 2**\n$$\\frac{2x}{2} = \\frac{4}{2}$$\n$$x = 2$$\n\n---\n\n**✓ Check the answer** by plugging x = 2 back into the original equation:\n$$2(2) + 3 = 4 + 3 = 7 ✓$$\n\n**The answer is x = 2**'

# %%
# Simple prompt to practice the system prompt functionality

messages = []

system = """
    You are a Python engeneer who writes very concise code.
    """

add_user_message(messages, "Write a Python function that checks a string for duplicate characters.")
answer = chat(messages, system)

answer
# Out:
# 'Here\'s a concise function that checks for duplicate characters in a string:\n\n```python\ndef has_duplicates(s: str) -> bool:\n    return len(s) != len(set(s))\n```\n\nIf you also want to **identify which characters are duplicated**:\n\n```python\ndef find_duplicates(s: str) -> set:\n    seen = set()\n    return {c for c in s if c in seen or seen.add(c)}\n```\n\n**Examples:**\n\n```python\nprint(has_duplicates("hello"))   # True  (\'l\' appears twice)\nprint(has_duplicates("world"))   # False (all unique)\nprint(has_duplicates(""))        # False\n\nprint(find_duplicates("hello"))        # {\'l\'}\nprint(find_duplicates("programming"))  # {\'g\', \'r\', \'m\'}\nprint(find_duplicates("python"))       # set()\n```\n\n**How they work:**\n| Function | Approach | Returns |\n|---|---|---|\n| `has_duplicates` | Compares string length to unique chars (`set`) | `bool` |\n| `find_duplicates` | Tracks seen chars, collects repeated ones | `set` of duplicate chars |'
